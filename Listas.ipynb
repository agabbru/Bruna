# %% [markdown]
# ESTRUTURA DE DADOS

# %% [markdown]
# LISTAS

# %%
# o que caracteriza uma lista é os valores entre []
lista_1 = ['arroz, carne, tomate, feijao']

# %%
print(lista_1)
print(type(lista_1))
# Out:
# ['arroz, carne, tomate, feijao']
# <class 'list'>

# %%
lista_2 = ['arroz', 'carne', 'tomate', 'feijao']

# %%
type(lista_2)
# Out:
# list

# %%
print(lista_2)
# Out:
# ['arroz', 'carne', 'tomate', 'feijao']

# %%
lista_3 = [100, 23 , 'Ciencia de Dados']

# %%
print(type(lista_3))
lista_3
# Out:
# <class 'list'>
# [100, 23, 'Ciencia de Dados']

# %%
item1 = lista_3[0]
item2 = lista_3[1]
item3 = lista_3[2]

# %%
print(item1, item2, item3)
# Out:
# 100 23 Ciencia de Dados

# %% [markdown]
# ATUALIZA UM ITEM DA LISTA

# %%
lista_2
# Out:
# ['arroz', 'carne', 'tomate', 'feijao']

# %%
lista_2[2] = 'Chocolate'

# %%
print(lista_2)
# Out:
# ['arroz', 'carne', 'Chocolate', 'feijao']

# %% [markdown]
# DELETANDO UM ITEM DA LISTA

# %%
del lista_2[3]

# %%
lista_2
# Out:
# ['arroz', 'carne', 'Chocolate']

# %% [markdown]
# LISTAS

# %%
# lista de listas
listas = [[1,2,3], [10,15,17],[10.1, 8.7, 2.3]]
print(listas)
# Out:
# [[1, 2, 3], [10, 15, 17], [10.1, 8.7, 2.3]]

# %%
# atribuindo um item da lista a uma variavel
a = listas[0]

# %%
a
# Out:
# [1, 2, 3]

# %%
b = a[0]

# %%
b
# Out:
# 1

# %%
list1 = listas[1]

# %%
list1
# Out:
# [10, 15, 17]

# %%
valor_1 = list1[0]

# %%
valor_1
# Out:
# 10

# %%
valor_2 = list1[1]

# %%
valor_2
# Out:
# 15

# %% [markdown]
# OPERAÇOES COM LISTAS

# %%
listas
# Out:
# [[1, 2, 3], [10, 15, 17], [10.1, 8.7, 2.3]]

# %%
a = listas[0][0]

# %%
a
# Out:
# 1

# %%
b = listas[1][2]

# %%
b
# Out:
# 17

# %%
c = listas[0][1] + 10

# %%
c
# Out:
# 12

# %%
d = listas[0][2] * c

# %%
d
# Out:
# 36

# %% [markdown]
# CONCATENANDO LISTAS

# %%
lista_s1 = [34 , 32 , 56]

# %%
lista_s1
# Out:
# [34, 32, 56]

# %%
lista_s2 = [21, 18, 85]

# %%
lista_s2
# Out:
# [21, 18, 85]

# %%
lista_total = lista_s1 + lista_s2

# %%
lista_total
# Out:
# [34, 32, 56, 21, 18, 85]

# %% [markdown]
# OPERADOR IN

# %%
lista_teste_op = [100, 2, -5, 3.4]

# %%
# verificando se o valor 10 pertence a lista
print(10 in lista_teste_op)
# Out:
# False

# %%
print(100 in lista_teste_op)
# Out:
# True

# %% [markdown]
# FUNÇOES BUILT-IN

# %%
lista_numeros = [10, 20, 50, -3.4]

# %%
# Funçao len() retorna o comprimento da lista
len(lista_numeros)
# Out:
# 4

# %%
# retorna o valor maximo da lista
max(lista_numeros)
# Out:
# 50

# %%
# retorna o valor minimo da lista 
min(lista_numeros)
# Out:
# -3.4

# %%
lista_formaçoes_dsa = ['Analista de dados','Cientista de dados', 'Engenheiro de dados']

# %%
# Adicionando um item da lista
lista_formaçoes_dsa.append('Engenheiro de IA')

# %%
print(lista_formaçoes_dsa)
# Out:
# ['Analista de dados', 'Cientista de dados', 'Engenheiro de dados', 'Engenheiro de IA']

# %%
# pode adicionar o mesmo item
lista_formaçoes_dsa.append('Engenheiro de IA')

# %%
print(lista_formaçoes_dsa)
# Out:
# ['Analista de dados', 'Cientista de dados', 'Engenheiro de dados', 'Engenheiro de IA', 'Engenheiro de IA']

# %%
lista_formaçoes_dsa.count('Engenheiro de IA')
# Out:
# 2

# %%
# criando uma lista vazia
a = []

# %%
a
# Out:
# []

# %%
type(a)
# Out:
# list

# %%
a.append(10)

# %%
a
# Out:
# [10]

# %%
a.append(50)

# %%
a
# Out:
# [10, 50]

# %%
old_lista = [1, 2, 5, 10]

# %%
new_lista = []

# %%
# copiando os itens de uma lista para outra
for item in old_lista:
    new_lista.append(item)

# %%
new_lista
# Out:
# [1, 2, 5, 10]

# %%
# para extender a lista ([])
cidades = ['Recife', 'Manaus','Salvador']
cidades.extend(['Fortaleza', 'Palmas'])
print(cidades)
# Out:
# ['Recife', 'Manaus', 'Salvador', 'Fortaleza', 'Palmas']

# %%
cidades.index('Salvador')
# Out:
# 2

# %%
# inserir elementos na lista: no indice 2 vou inserir o numero 110
cidades.insert(2, 110)

# %%
cidades
# Out:
# ['Recife', 'Manaus', 110, 'Salvador', 'Fortaleza', 'Palmas']

# %%
cidades.remove(110)

# %%
cidades
# Out:
# ['Recife', 'Manaus', 'Salvador', 'Fortaleza', 'Palmas']

# %%
# reverte a lista ao contrario 
cidades.reverse()

# %%
cidades
# Out:
# ['Palmas', 'Fortaleza', 'Salvador', 'Manaus', 'Recife']

# %%
n = [3, 4, 2, 1]

# %%
n
# Out:
# [3, 4, 2, 1]

# %%
# Ordena a lista
n.sort()

# %%
n
# Out:
# [1, 2, 3, 4]
